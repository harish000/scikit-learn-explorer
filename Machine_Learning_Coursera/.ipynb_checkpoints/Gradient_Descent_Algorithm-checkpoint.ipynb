# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
data = np.loadtxt('ex1data1.txt',delimiter=',')
X = np.c_[np.ones(data.shape[0]),data[:,0]]
y = np.c_[data[:,1]]

# %%
len(np.ones(data.shape[0]))
# Out:
# 97

# %%
plt.scatter(X[:,1], y, s=30, c='r', marker='x', linewidths=1)
plt.xlim(4,24)
plt.xlabel('Population')
plt.ylabel('Profit');
plt.show()

# %% [raw]
# Computing Cost Function

# %%
def computeCost(X,y,theta = [[0],[0]]):
    m = y.size
    J=0
    
    h=X.dot(theta)
    # Cost function a mentioned in the formula [32]
    J=1/(2*m)*np.sum(np.square(h-y))
    return(J)

# %%
computeCost(X,y)
# Out:
# 32.072733877455676

# %%
def gradientDescent(X,y,theta=[[0],[0]],iteration=1500,alpha=0.01):
    m = y.size
    
    # Initializing J_history value to zero
    J_history = np.zeros(iteration)
    
    for iter in np.arange(iteration):
        h = X.dot(theta)
        # Applying the formula in [31] for theta and performing simultaneous update
        theta = theta - alpha*(1/m)*(X.T.dot(h-y))
        J_history[iter] = computeCost(X,y,theta)
    return(theta,J_history)

# %%
theta, cost_J = gradientDescent(X,y)

# %%
theta
# Out:
# array([[-3.63029144],
#        [ 1.16636235]])

# %%
cost_J
# Out:
# array([ 6.73719046,  5.93159357,  5.90115471, ...,  4.48343473,
#         4.48341145,  4.48338826])

# %%
plt.plot(cost_J)
plt.ylabel('Cost J')
plt.xlabel('Iterations');

# %% [raw]
# Predicting the value using theta

# %%
theta.T.dot([10000,35000])
# Out:
# array([ 4519.7678677])

# %%
theta.T.dot([10000,70000])
# Out:
# array([ 45342.45012945])

# %%
#xx and yy are parameters for the fitting line
xx = np.arange(1,25)
#yy is the fitted line theta(0)+theta(1)*xx
yy = theta[0]+theta[1]*xx

# Plot gradient descent
plt.scatter(X[:,1], y, s=50, c='r', marker='x', linewidths=1)
plt.plot(xx,yy, label='Gradient descent')

plt.xlim(3,25)
plt.xlabel('Population')
plt.ylabel('Profit')

# %%
data_multi = np.loadtxt('ex1data2.txt',delimiter=',')

# %%
X_multi = np.c_[np.ones(data_multi.shape[0]),data_multi[:,0:2]]
y_multi = np.c_[data_multi[:,2]]

# %%
def featureNormalize(X_multi):
    X_norm = np.c_[np.zeros(X_multi.T.shape)]
    mu = (np.zeros(X_norm.T.shape[1]))
    sigma = (np.zeros(X_norm.T.shape[1]))
    i=0
    for col in X_multi.T:
        col_mean = np.mean(col)
        col_std = np.std(col)
        mu[i]=col_mean
        sigma[i]=col_std
        temp = list()
        for row in col:
            val = (row-col_mean)/col_std
            temp.append(val)
        X_norm[i] = temp
        i=i+1
    X_norm[0] = [1]*len(X_multi)
    return X_norm.T,mu,sigma

# %%
X_norm, mu, sigma = featureNormalize(X_multi)

# %%
def computeCost(X,y,theta):
    m = y.size
    J=0
    
    h=X.dot(theta)
    # Cost function a mentioned in the formula [32]
    J=1/(2*m)*np.sum(np.square(h-y))
    return(J)

# %%
def gradientDescentMulti(X, y, alpha, iteration,theta):
    m = y.size
    J_history = np.zeros(iteration)
    for iter in np.arange(iteration):
        h = X.dot(theta)
        theta = theta - alpha*(1/m)*(X.T.dot(h-y))
        J_history[iter] = computeCost(X,y,theta)
    return(theta,J_history)

# %%
alpha_multi = 0.01
num_iters=400
theta = np.zeros(X_norm.shape[1])
theta,J_history = gradientDescentMulti(X_norm,y_multi,alpha_multi,num_iters,theta)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-ae721ce61857> in <module>()
#       2 num_iters=400
#       3 theta = np.zeros(X_norm.shape[1])
# ----> 4 theta,J_history = gradientDescentMulti(X_norm,y_multi,alpha_multi,num_iters,theta)
#
# <ipython-input-120-2d01a244b5a3> in gradientDescentMulti(X, y, alpha, iteration, theta)
#       5         h = X.dot(theta.T)
#       6         theta = theta - alpha*(1/m)*((h-y).T.dot(X))
# ----> 7         J_history[iter] = computeCost(X,y,theta)
#       8     return(theta,J_history)
#
# <ipython-input-119-abb1f61cb4a2> in computeCost(X, y, theta)
#       3     J=0
#       4
# ----> 5     h=X.dot(theta)
#       6     # Cost function a mentioned in the formula [32]
#       7     J=1/(2*m)*np.sum(np.square(h-y))
#
# ValueError: shapes (47,3) and (47,3) not aligned: 3 (dim 1) != 47 (dim 0)

# %%
theta
# Out:
# array([[ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407],
#        [ 334302.06399328,   99411.44947359,    3267.01285407]])

# %%
h = X_norm.dot(theta)
theta = np.zeros(X_norm.shape[1])

# %%
(alpha_multi*(1/y_multi.size)*X_norm.T.dot(h-y_multi)).shape
# Out:
# (3, 47)

# %%
theta.shape
# Out:
# (3,)
